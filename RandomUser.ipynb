# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5066 sha256=9d0535dd7eb44e149d72f04afb9ff1ebd9622490c9ed89cb0531a84652bfe6a2
#   Stored in directory: /root/.cache/pip/wheels/b8/f3/19/6a938647065b4bb2471a9d063647d14d4fcc3236731f4e2b53
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %%
from randomuser import RandomUser
import pandas as pd

# %%
r = RandomUser()

# %%
some_list = r.generate_users(10) # get a list of random 10 users

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x7aff14e2f640>,
#  <randomuser.RandomUser at 0x7aff14e2e260>,
#  <randomuser.RandomUser at 0x7aff14e2f1c0>,
#  <randomuser.RandomUser at 0x7aff14e2eb60>,
#  <randomuser.RandomUser at 0x7aff14e2f6a0>,
#  <randomuser.RandomUser at 0x7aff14e2f9d0>,
#  <randomuser.RandomUser at 0x7aff14e2fa00>,
#  <randomuser.RandomUser at 0x7afee65c2c80>,
#  <randomuser.RandomUser at 0x7afee65c3190>,
#  <randomuser.RandomUser at 0x7afee65c3160>]

# %%
name = r.get_full_name()

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Nelli Tuominen   nelli.tuominen@example.com
# Dylan Mackay   dylan.mackay@example.com
# Jeremy Ford   jeremy.ford@example.com
# Vidar Birkeland   vidar.birkeland@example.com
# آوا نجاتی   aw.njty@example.com
# Buse Topaloğlu   buse.topaloglu@example.com
# Anton Bezuijen   anton.bezuijen@example.com
# Sofia Denys   sofia.denys@example.com
# Rasmus Laakso   rasmus.laakso@example.com
# Suzanne Wenzel   suzanne.wenzel@example.com

# %%
## code to get picture
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/women/41.jpg
# https://randomuser.me/api/portraits/men/27.jpg
# https://randomuser.me/api/portraits/men/41.jpg
# https://randomuser.me/api/portraits/men/89.jpg
# https://randomuser.me/api/portraits/women/26.jpg
# https://randomuser.me/api/portraits/women/16.jpg
# https://randomuser.me/api/portraits/men/48.jpg
# https://randomuser.me/api/portraits/women/70.jpg
# https://randomuser.me/api/portraits/men/1.jpg
# https://randomuser.me/api/portraits/women/85.jpg

# %%
def get_users():
    users =[]

    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),
                      "City":user.get_city(),"State":user.get_state(),
                      "Email":user.get_email(), "DOB":user.get_dob(),
                      "Picture":user.get_picture()})

    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                  Name  Gender             City               State  \
# 0          Teresa Day  female          Lisburn         West Sussex
# 1        Torje Stokke    male       Finnbråtan                Oslo
# 2       Canto Moreira    male           Canoas  Mato Grosso do Sul
# 3  Alexander Harrison    male          Sallins           Waterford
# 4     Nathan Gauthier    male  Rueil-Malmaison        Haute-Savoie
# 5        Shane Burton    male         Midleton           Cork City
# 6        Lotta Laakso  female           Laihia               Åland
# 7    Claus-Peter Loch    male     Bad Bevensen             Sachsen
# 8   Geraldine Schurig  female          Görlitz              Bremen
# 9       Rene Anderson    male        St Albans      Worcestershire
#
#                             Email                       DOB  \
# 0          teresa.day@example.com  1978-09-05T17:55:45.021Z
# 1        torje.stokke@example.com  1966-12-09T10:17:12.100Z
# 2       canto.moreira@example.com  1972-06-30T19:49:14.519Z
# 3  alexander.harrison@example.com  1982-06-19T11:08:57.771Z
# 4     nathan.gauthier@example.com  1948-07-06T15:04:30.134Z
# 5        shane.burton@example.com  1978-06-24T00:15:40.255Z
# 6        lotta.laakso@example.com  1974-07-05T07:46:29.600Z
# 7    claus-peter.loch@example.com  1958-09-22T06:18:12.155Z
# 8   geraldine.schurig@example.com  1967-06-20T18:14:49.726Z
# 9       rene.anderson@example.com  1970-06-15T17:31:35.779Z
#
#                                             Picture
# 0   https://randomuser.me/api/portraits/women/7.jpg
# 1    https://randomuser.me/api/portraits/men/10.jpg
# 2    https://randomuser.me/api/portraits/men/52.jpg
# 3     https://randomuser.me/api/portraits/men/3.jpg
# 4    https://randomuser.me/api/portraits/men/21.jpg
# 5     https://randomuser.me/api/portraits/men/0.jpg
# 6  https://randomuser.me/api/portraits/women/93.jpg
# 7    https://randomuser.me/api/portraits/men/24.jpg
# 8  https://randomuser.me/api/portraits/women/85.jpg
# 9    https://randomuser.me/api/portraits/men/32.jpg
